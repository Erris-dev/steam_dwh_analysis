# %%
# Cell 1 — path setup + all imports
import sys
from pathlib import Path

ROOT = Path.cwd().parent
sys.path.insert(0, str(ROOT))

import json
import re
from datetime import datetime, timezone

import pandas as pd

from config.settings import (
    APP_DETAILS_DIR,
    PLAYER_COUNTS_DIR,
    REVIEWS_DIR,
    ACHIEVEMENTS_DIR,
    STEAMSPY_DIR,
    DATA_DIR,
)
